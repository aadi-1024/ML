# %%
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv('./train.csv')

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp
# count   891.000000  891.000000  891.000000  714.000000  891.000000  \
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# data = data.drop(data[data.isna()].index)
data = data.drop(data[data['Age'].isnull()].index)

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp
# count   714.000000  714.000000  714.000000  714.000000  714.000000  \
# mean    448.582633    0.406162    2.236695   29.699118    0.512605
# std     259.119524    0.491460    0.838250   14.526497    0.929783
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     222.250000    0.000000    1.000000   20.125000    0.000000
# 50%     445.000000    0.000000    2.000000   28.000000    0.000000
# 75%     677.750000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    5.000000
#
#             Parch        Fare
# count  714.000000  714.000000
# mean     0.431373   34.694514
# std      0.853289   52.918930
# min      0.000000    0.000000
# 25%      0.000000    8.050000
# 50%      0.000000   15.741700
# 75%      1.000000   33.375000
# max      6.000000  512.329200

# %%
sns.set_theme()

# %%
data.loc[:,'PassengerId'] = data['Survived']
sns.relplot(data, hue='Survived')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 2
#       1 data.loc[:,'PassengerId'] = data['Survived']
# ----> 2 sns.relplot(data, hue='Survived')
#
# File ~/Documents/ML/env/lib/python3.11/site-packages/seaborn/relational.py:862, in relplot(data, x, y, hue, size, style, units, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     859     kwargs.pop("ax")
#     861 # Use the full dataset to map the semantics
# --> 862 p = plotter(
#     863     data=data,
#     864     variables=plotter.get_semantics(locals()),
#     865     legend=legend,
#     866 )
#     867 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     868 p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# ...
